# %% [markdown]
# # Check the Chapter 7 IRF
#
# Piers

# %%
#from ar6.twolayermodel import TwoLayerModel
import numpy as np
import matplotlib.pyplot as pl
from tqdm import tqdm
import scipy.stats as st
import pandas as pd
import matplotlib.pyplot as pl
import os
from matplotlib import gridspec, rc
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from netCDF4 import Dataset
import warnings
from openscm_units import unit_registry  # pip install openscm-units
from openscm_twolayermodel import ImpulseResponseModel, TwoLayerModel, constants  # pip install openscm-twolayermodel
from scmdata import ScmRun  # pip install scmdata

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
recommend_paras = pd.read_csv("../../data_in/recommended_irf_from_2xCO2_2021_02_25_222758.csv").iloc[0, :]
recommend_paras

# %%
du = (
    recommend_paras["C (W yr / m^2 / K)"] 
    * unit_registry("W yr / m^2 / delta_degC")
    / constants.DENSITY_WATER
    / constants.HEAT_CAPACITY_WATER
).to("m")
display(du)

dl = (
    recommend_paras["C_d (W yr / m^2 / K)"] 
    * unit_registry("W yr / m^2 / delta_degC")
    / constants.DENSITY_WATER
    / constants.HEAT_CAPACITY_WATER
).to("m")
display(dl)
# Out:
# 57.739533588502034 <Unit('meter')>
# 1110.8078463278985 <Unit('meter')>

# %%
AR6_forcing = pd.read_csv('../../data_in//AR6_ERF_1750-2019.csv', index_col=0)

# %%
ch6_forcing = pd.read_csv('/Users/earpmf/OneDrive - University of Leeds/PYTHON/AR6_CH6_RCMIPFIGS-fig_6.12_contrib_ERF_GSAT_hist/ar6_ch6_rcmipfigs/data_out/historic_delta_GSAT/hist_ERF_est.csv', index_col=0)

# %%
ch6_GSAT = pd.read_csv('/Users/earpmf/OneDrive - University of Leeds/PYTHON/AR6_CH6_RCMIPFIGS-fig_6.12_contrib_ERF_GSAT_hist/ar6_ch6_rcmipfigs/data_out/historic_delta_GSAT/Delta_T_timeseriies.csv', index_col=0)

# %%
ch6_forcing
# Out:
#            CO2       N2O       CH4       NOx       SO2        BC        OC  \
# 1750  0.000000  0.000000  0.000000 -0.000000 -0.000000  0.000000 -0.000000
# 1751  0.001126  0.000077  0.000832 -0.000001 -0.000053  0.000014 -0.000119
# 1752  0.002252  0.000154  0.001663 -0.000002 -0.000091  0.000028 -0.000237
# 1753  0.003378  0.000230  0.002495 -0.000004 -0.000124  0.000043 -0.000356
# 1754  0.004505  0.000307  0.003326 -0.000005 -0.000160  0.000057 -0.000474
# ...        ...       ...       ...       ...       ...       ...       ...
# 2015  1.894420  0.223577  1.171873 -0.295162 -0.994594  0.065084 -0.201918
# 2016  1.948068  0.226732  1.180530 -0.291303 -0.953730  0.063885 -0.202334
# 2017  1.981696  0.230251  1.188029 -0.290949 -0.918519  0.063844 -0.202386
# 2018  2.019078  0.234670  1.197088 -0.288873 -0.913279  0.063397 -0.200986
# 2019  2.057554  0.238130  1.206157 -0.286158 -0.898688  0.062828 -0.199196
#
#            NH3       VOC        HC
# 1750 -0.000000  0.000000  0.000000
# 1751 -0.000005  0.000177  0.000000
# 1752 -0.000010  0.000354  0.000000
# 1753 -0.000014  0.000530  0.000000
# 1754 -0.000019  0.000706  0.000000
# ...        ...       ...       ...
# 2015 -0.029726  0.481837  0.200667
# 2016 -0.030035  0.464815  0.201919
# 2017 -0.030378  0.458057  0.203356
# 2018 -0.030660  0.452975  0.204997
# 2019 -0.030954  0.448353  0.206392
#
# [270 rows x 10 columns]

# %%
ch6_GSAT

# %%
impulse_response = ImpulseResponseModel(
    d1=recommend_paras["d1 (yr)"] * unit_registry("yr"),
    d2=recommend_paras["d2 (yr)"] * unit_registry("yr"),
    q1=recommend_paras["q1 (K / (W / m^2))"] * unit_registry("delta_degC / (W / m^2)"),
    q2=recommend_paras["q2 (K / (W / m^2))"] * unit_registry("delta_degC / (W / m^2)"),
    efficacy=recommend_paras["efficacy (dimensionless)"] * unit_registry("dimensionless"),
)
res_impulse_response = impulse_response.run_scenarios()

# %%
erf = ch6_forcing['CO2']
scenario = "chapter 6 CO2"
unit = "W/m^2"

driver = ScmRun(
    data=erf,
    index=1750 + np.arange(len(erf)),
    columns={
        "unit": unit,
        "model": "custom",
        "scenario": scenario,
        "region": "World",
        "variable": "Effective Radiative Forcing",
    },
)
driver

impulse_response = ImpulseResponseModel(
    d1=recommend_paras["d1 (yr)"] * unit_registry("yr"),
    d2=recommend_paras["d2 (yr)"] * unit_registry("yr"),
    q1=recommend_paras["q1 (K / (W / m^2))"] * unit_registry("delta_degC / (W / m^2)"),
    q2=recommend_paras["q2 (K / (W / m^2))"] * unit_registry("delta_degC / (W / m^2)"),
    efficacy=recommend_paras["efficacy (dimensionless)"] * unit_registry("dimensionless"),
)
res_impulse_response = impulse_response.run_scenarios(driver)

two_layer = TwoLayerModel(
    # the naming is confusing because I follow Geoffroy, Ch. 7 Appendix does its own thing
    # the units should be clear
    lambda0=recommend_paras["alpha (W / m^2 / K)"] * unit_registry("W/m^2/delta_degC"),
    du=du,
    dl=dl,
    a=0.0 * unit_registry("watt / delta_degree_Celsius ** 2 / meter ** 2"),
    efficacy=recommend_paras["efficacy (dimensionless)"] * unit_registry("dimensionless"),
    eta=recommend_paras["kappa (W / m^2 / K)"] * unit_registry("W / m^2 / K")
)
res_two_layer = two_layer.run_scenarios(driver)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='scenarios', max=1.0, style=ProgressStyl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='scenarios', max=1.0, style=ProgressStyl…

# %%
erf

# %%
res_impulse_response.head()
# Out:
# time                                                                                                                                                                                                                                                1750-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing         0.0
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1           0.0
#                                                                                                                                                                                                                        Surface Temperature|Box 2           0.0
#                                                                                                                                                                                                                        Surface Temperature                 0.0
#                                                                                                                                                                                                             W/m^2      Heat Uptake                         0.0
#
# time                                                                                                                                                                                                                                                1751-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.001126
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.000000
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.000000
#                                                                                                                                                                                                                        Surface Temperature            0.000000
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.000000
#
# time                                                                                                                                                                                                                                                1752-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.002252
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.000127
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.000001
#                                                                                                                                                                                                                        Surface Temperature            0.000128
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.001126
#
# time                                                                                                                                                                                                                                                1753-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.003378
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.000348
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.000004
#                                                                                                                                                                                                                        Surface Temperature            0.000351
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.002082
#
# time                                                                                                                                                                                                                                                1754-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.004505
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.000639
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.000008
#                                                                                                                                                                                                                        Surface Temperature            0.000647
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.002909
#
# time                                                                                                                                                                                                                                                1755-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.005631
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.000984
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.000013
#                                                                                                                                                                                                                        Surface Temperature            0.000996
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.003641
#
# time                                                                                                                                                                                                                                                1756-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.006757
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.001367
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.000019
#                                                                                                                                                                                                                        Surface Temperature            0.001386
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.004301
#
# time                                                                                                                                                                                                                                                1757-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.007883
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.001780
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.000026
#                                                                                                                                                                                                                        Surface Temperature            0.001807
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.004907
#
# time                                                                                                                                                                                                                                                1758-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.009009
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.002216
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.000035
#                                                                                                                                                                                                                        Surface Temperature            0.002251
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.005472
#
# time                                                                                                                                                                                                                                                1759-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.010135
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.002667
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.000045
#                                                                                                                                                                                                                        Surface Temperature            0.002712
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.006007
#
# time                                                                                                                                                                                                                                                ...  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable                     ...
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing  ...
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1    ...
#                                                                                                                                                                                                                        Surface Temperature|Box 2    ...
#                                                                                                                                                                                                                        Surface Temperature          ...
#                                                                                                                                                                                                             W/m^2      Heat Uptake                  ...
#
# time                                                                                                                                                                                                                                                2010-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.724717
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.711696
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.088505
#                                                                                                                                                                                                                        Surface Temperature            0.800201
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.645209
#
# time                                                                                                                                                                                                                                                2011-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.754122
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.725291
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.090126
#                                                                                                                                                                                                                        Surface Temperature            0.815417
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.661707
#
# time                                                                                                                                                                                                                                                2012-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.785560
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.738747
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.091774
#                                                                                                                                                                                                                        Surface Temperature            0.830521
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.670896
#
# time                                                                                                                                                                                                                                                2013-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.828416
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.752329
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.093451
#                                                                                                                                                                                                                        Surface Temperature            0.845780
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.682268
#
# time                                                                                                                                                                                                                                                2014-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.858446
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.767288
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.095170
#                                                                                                                                                                                                                        Surface Temperature            0.862458
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.704852
#
# time                                                                                                                                                                                                                                                2015-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.894420
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.781833
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.096917
#                                                                                                                                                                                                                        Surface Temperature            0.878750
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.712720
#
# time                                                                                                                                                                                                                                                2016-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.948068
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.796738
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.098698
#                                                                                                                                                                                                                        Surface Temperature            0.895436
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.727047
#
# time                                                                                                                                                                                                                                                2017-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.981696
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.813897
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.100533
#                                                                                                                                                                                                                        Surface Temperature            0.914430
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.758526
#
# time                                                                                                                                                                                                                                                2018-01-01  \
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    2.019078
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.830490
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.102400
#                                                                                                                                                                                                                        Surface Temperature            0.932890
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.766905
#
# time                                                                                                                                                                                                                                                2019-01-01
# climate_model                  d1 (a)   d2 (a)     efficacy (dimensionless) model  q1 (delta_degree_Celsius * meter ** 2 / watt) q2 (delta_degree_Celsius * meter ** 2 / watt) region run_idx scenario      unit       variable
# two_timescale_impulse_response 3.424102 285.003478 1.027856                 custom 0.443768                                      0.319591                                      World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    2.057554
#                                                                                                                                                                                                             delta_degC Surface Temperature|Box 1      0.847082
#                                                                                                                                                                                                                        Surface Temperature|Box 2      0.104301
#                                                                                                                                                                                                                        Surface Temperature            0.951383
#                                                                                                                                                                                                             W/m^2      Heat Uptake                    0.779755
#
# [5 rows x 270 columns]

# %%
res_two_layer.head()
# Out:
# time                                                                                                                                                                                                                                                                            1750-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing         0.0
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper           0.0
#                                                                                                                                                                                                                                                    Surface Temperature|Lower           0.0
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                         0.0
#
# time                                                                                                                                                                                                                                                                            1751-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.001126
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.000000
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.000000
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.000000
#
# time                                                                                                                                                                                                                                                                            1752-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.002252
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.000147
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.000000
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.001126
#
# time                                                                                                                                                                                                                                                                              1753-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing  3.378424e-03
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper    3.990077e-04
#                                                                                                                                                                                                                                                    Surface Temperature|Lower    8.808963e-07
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                  2.055824e-03
#
# time                                                                                                                                                                                                                                                                            1754-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.004505
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.000725
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.000003
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.002846
#
# time                                                                                                                                                                                                                                                                            1755-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.005631
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.001104
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.000008
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.003537
#
# time                                                                                                                                                                                                                                                                            1756-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.006757
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.001522
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.000014
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.004157
#
# time                                                                                                                                                                                                                                                                            1757-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.007883
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.001966
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.000023
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.004727
#
# time                                                                                                                                                                                                                                                                            1758-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.009009
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.002430
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.000035
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.005260
#
# time                                                                                                                                                                                                                                                                            1759-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    0.010135
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.002908
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.000049
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.005767
#
# time                                                                                                                                                                                                                                                                            ...  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable                     ...
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing  ...
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper    ...
#                                                                                                                                                                                                                                                    Surface Temperature|Lower    ...
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                  ...
#
# time                                                                                                                                                                                                                                                                            2010-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.724717
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.807222
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.199250
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.635757
#
# time                                                                                                                                                                                                                                                                            2011-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.754122
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.822509
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.202888
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.652342
#
# time                                                                                                                                                                                                                                                                            2012-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.785560
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.837643
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.206596
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.661435
#
# time                                                                                                                                                                                                                                                                            2013-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.828416
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.852944
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.210372
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.672767
#
# time                                                                                                                                                                                                                                                                            2014-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.858446
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.869862
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.214217
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.695297
#
# time                                                                                                                                                                                                                                                                            2015-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.894420
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.886263
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.218140
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.702843
#
# time                                                                                                                                                                                                                                                                            2016-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.948068
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.903081
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.222138
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.717027
#
# time                                                                                                                                                                                                                                                                            2017-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    1.981696
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.922515
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.226213
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.748329
#
# time                                                                                                                                                                                                                                                                            2018-01-01  \
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    2.019078
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.941199
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.230379
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.756121
#
# time                                                                                                                                                                                                                                                                            2019-01-01
# a (watt / delta_degree_Celsius ** 2 / meter ** 2) climate_model dl (meter)  du (meter) efficacy (dimensionless) eta (watt / kelvin / meter ** 2) lambda0 (watt / delta_degree_Celsius / meter ** 2) model  region run_idx scenario      unit       variable
# 0.0                                               two_layer     1110.807846 57.739534  1.027856                 0.880636                         1.31                                               custom World  0       chapter 6 CO2 W/m^2      Effective Radiative Forcing    2.057554
#                                                                                                                                                                                                                                         delta_degC Surface Temperature|Upper      0.959853
#                                                                                                                                                                                                                                                    Surface Temperature|Lower      0.234633
#                                                                                                                                                                                                                                         W/m^2      Heat Uptake                    0.768670
#
# [4 rows x 270 columns]

# %%
ch6_GSAT
# Out:
#            CO2       N2O       CH4           NOx       SO2        BC  \
# year
# 1750  0.000000  0.000000  0.000000  0.000000e+00  0.000000  0.000000
# 1751  0.000147  0.000010  0.000109 -1.534412e-07 -0.000007  0.000002
# 1752  0.000405  0.000028  0.000299 -4.229968e-07 -0.000017  0.000005
# 1753  0.000745  0.000051  0.000550 -7.781722e-07 -0.000029  0.000009
# 1754  0.001147  0.000078  0.000847 -1.198815e-06 -0.000043  0.000014
# ...        ...       ...       ...           ...       ...       ...
# 2015  1.017607  0.121303  0.668071 -1.714400e-01 -0.669099  0.039113
# 2016  1.039232  0.123298  0.673168 -1.701955e-01 -0.649515  0.038738
# 2017  1.060235  0.125301  0.678216 -1.692870e-01 -0.630467  0.038466
# 2018  1.081272  0.127427  0.683431 -1.684043e-01 -0.615726  0.038218
# 2019  1.102487  0.129522  0.688775 -1.674562e-01 -0.602978  0.037973
#
#             OC           NH3       VOC        HC
# year
# 1750  0.000000  0.000000e+00  0.000000  0.000000
# 1751 -0.000016 -6.248794e-07  0.000023  0.000000
# 1752 -0.000043 -1.717622e-06  0.000064  0.000000
# 1753 -0.000078 -3.160974e-06  0.000117  0.000000
# 1754 -0.000121 -4.867373e-06  0.000180  0.000000
# ...        ...           ...       ...       ...
# 2015 -0.119377 -1.638171e-02  0.296524  0.108567
# 2016 -0.119548 -1.655779e-02  0.292309  0.109317
# 2017 -0.119725 -1.674113e-02  0.288373  0.110115
# 2018 -0.119717 -1.692205e-02  0.284861  0.110975
# 2019 -0.119520 -1.710263e-02  0.281726  0.111851
#
# [270 rows x 10 columns]

# %%
print (0.95/1.1)
# Out:
# 0.8636363636363635
